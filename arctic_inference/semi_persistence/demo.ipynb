# %% [markdown]
# ### Demo: Serving many models on 4 GPUs by model multiplexing

# %%
import datetime, logging, os, sys, warnings

os.environ["PYTHONWARNINGS"] = "ignore"
os.environ["VLLM_LOGGING_LEVEL"] = "ERROR"
os.environ["FLASHINFER_LOG_LEVEL"] = "ERROR"
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
warnings.filterwarnings("ignore")
logging.disable(logging.WARNING)

import orchestrator
from orchestrator import Orchestrator

orchestrator._console_stream = sys.stderr

log_path = f"demo_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
_log_file = open(log_path, "w")
os.dup2(_log_file.fileno(), 1)
os.dup2(_log_file.fileno(), 2)
sys.stdout = _log_file

Orchestrator.init(local_cache="/data-fast/model-cache")
Orchestrator.print_status()
# Out:
# Orchestrator  local_cache=/data-fast/model-cache
#
# GPUs (4):
#   GPU 0: NVIDIA H200  10.9 / 140.4 GiB used  (129.5 GiB free)
#   GPU 1: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 2: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 3: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#
# No models registered.

# %% [markdown]
# Now we have 17 models in hand. We only need a vllm config to define an instance.

# %%
vllm_config_1  = {"model": "Qwen/Qwen3-32B"}
vllm_config_2  = {"model": "Qwen/Qwen3-14B"}
vllm_config_3  = {"model": "Qwen/Qwen3-8B"}
vllm_config_4  = {"model": "Qwen/Qwen3-4B"}
vllm_config_5  = {"model": "Qwen/Qwen3-1.7B"}
vllm_config_6  = {"model": "Qwen/Qwen3-0.6B"}
vllm_config_7  = {"model": "Qwen/Qwen3-30B-A3B"}
vllm_config_8  = {"model": "Qwen/Qwen3-30B-A3B-Base"}
vllm_config_9  = {"model": "Qwen/Qwen3-14B-Base"}
vllm_config_10 = {"model": "Qwen/Qwen3-8B-Base"}
vllm_config_11 = {"model": "Qwen/Qwen3-4B-Base"}
vllm_config_12 = {"model": "Qwen/Qwen3-1.7B-Base"}
vllm_config_13 = {"model": "Qwen/Qwen3-0.6B-Base"}
vllm_config_14 = {"model": "Qwen/Qwen3-30B-A3B-Instruct-2507"}
vllm_config_15 = {"model": "Qwen/Qwen3-4B-Instruct-2507"}
vllm_config_16 = {"model": "Qwen/Qwen3-30B-A3B-Thinking-2507"}
vllm_config_17 = {"model": "Qwen/Qwen3-4B-Thinking-2507"}

# %% [markdown]
# Now we need to register the model. This a start for each model.

# %%
Orchestrator.register("qwen3-32b-instruct",             vllm_config_1)
Orchestrator.register("qwen3-14b-instruct",             vllm_config_2)
Orchestrator.register("qwen3-8b-instruct",              vllm_config_3)
Orchestrator.register("qwen3-4b-instruct",              vllm_config_4)
Orchestrator.register("qwen3-1.7b-instruct",            vllm_config_5)
Orchestrator.register("qwen3-0.6b-instruct",            vllm_config_6)
Orchestrator.register("qwen3-30b-a3b-instruct",         vllm_config_7)
Orchestrator.register("qwen3-30b-a3b-base",             vllm_config_8)
Orchestrator.register("qwen3-14b-base",                 vllm_config_9)
Orchestrator.register("qwen3-8b-base",                  vllm_config_10)
Orchestrator.register("qwen3-4b-base",                  vllm_config_11)
Orchestrator.register("qwen3-1.7b-base",                vllm_config_12)
Orchestrator.register("qwen3-0.6b-base",                vllm_config_13)
Orchestrator.register("qwen3-30b-a3b-instruct-2507",    vllm_config_14)
Orchestrator.register("qwen3-4b-instruct-2507",         vllm_config_15)
Orchestrator.register("qwen3-30b-a3b-thinking-2507",    vllm_config_16)
Orchestrator.register("qwen3-4b-thinking-2507",         vllm_config_17)

Orchestrator.wait()
# Out:
# qwen3-32b-instruct: register received
# qwen3-14b-instruct: register received
# qwen3-8b-instruct: register received
# qwen3-4b-instruct: register received
# qwen3-1.7b-instruct: register received
# qwen3-0.6b-instruct: register received
# qwen3-30b-a3b-instruct: register received
# qwen3-30b-a3b-base: register received
# qwen3-14b-base: register received
# qwen3-8b-base: register received
# qwen3-4b-base: register received
# qwen3-1.7b-base: register received
# qwen3-0.6b-base: register received
# qwen3-30b-a3b-instruct-2507: register received
# qwen3-4b-instruct-2507: register received
# qwen3-30b-a3b-thinking-2507: register received
# qwen3-4b-thinking-2507: register received
# qwen3-0.6b-base: acquired GPU 0
# qwen3-8b-base: acquired GPU 1
# qwen3-4b-thinking-2507: acquired GPU 2
# qwen3-4b-instruct: acquired GPU 3
# qwen3-30b-a3b-base: waiting for GPU...
# qwen3-4b-instruct-2507: waiting for GPU...
# qwen3-14b-base: waiting for GPU...
# qwen3-4b-base: waiting for GPU...
# qwen3-30b-a3b-instruct-2507: waiting for GPU...
# qwen3-1.7b-base: waiting for GPU...
# qwen3-0.6b-instruct: waiting for GPU...
# qwen3-30b-a3b-thinking-2507: waiting for GPU...
# qwen3-1.7b-instruct: waiting for GPU...
# qwen3-14b-instruct: waiting for GPU...
# qwen3-32b-instruct: waiting for GPU...
# qwen3-8b-instruct: waiting for GPU...
# qwen3-30b-a3b-instruct: waiting for GPU...
# qwen3-0.6b-base: registered (wait=0.2s, register=22.9s, total=23.1s)
# qwen3-30b-a3b-thinking-2507: acquired GPU 0
# qwen3-4b-instruct: registered (wait=0.3s, register=28.8s, total=29.2s)
# qwen3-1.7b-instruct: acquired GPU 3
# qwen3-4b-thinking-2507: registered (wait=0.3s, register=29.4s, total=29.6s)
# qwen3-1.7b-base: acquired GPU 2
# qwen3-8b-base: registered (wait=0.3s, register=30.0s, total=30.3s)
# qwen3-30b-a3b-base: acquired GPU 1
# qwen3-1.7b-instruct: registered (wait=29.2s, register=21.9s, total=51.1s)
# qwen3-32b-instruct: acquired GPU 3
# qwen3-1.7b-base: registered (wait=29.7s, register=22.0s, total=51.6s)
# qwen3-4b-instruct-2507: acquired GPU 2
# qwen3-30b-a3b-thinking-2507: registered (wait=23.1s, register=52.2s, total=75.3s)
# qwen3-14b-instruct: acquired GPU 0
# qwen3-4b-instruct-2507: registered (wait=51.6s, register=26.6s, total=78.2s)
# qwen3-0.6b-instruct: acquired GPU 2
# qwen3-30b-a3b-base: registered (wait=30.3s, register=49.9s, total=80.2s)
# qwen3-30b-a3b-instruct-2507: acquired GPU 1
# qwen3-0.6b-instruct: registered (wait=78.2s, register=22.4s, total=100.6s)
# qwen3-14b-base: acquired GPU 2
# qwen3-32b-instruct: registered (wait=51.1s, register=57.0s, total=108.1s)
# qwen3-4b-base: acquired GPU 3
# qwen3-14b-instruct: registered (wait=75.3s, register=35.9s, total=111.3s)
# qwen3-8b-instruct: acquired GPU 0
# qwen3-30b-a3b-instruct-2507: registered (wait=80.2s, register=49.7s, total=129.8s)
# qwen3-30b-a3b-instruct: acquired GPU 1
# qwen3-4b-base: registered (wait=108.1s, register=25.9s, total=134.0s)
# qwen3-14b-base: registered (wait=100.6s, register=36.6s, total=137.1s)
# qwen3-8b-instruct: registered (wait=111.3s, register=29.4s, total=140.6s)
# qwen3-30b-a3b-instruct: registered (wait=129.8s, register=52.6s, total=182.4s)

# %% [markdown]
# All models are registered and checkpointed (0 GPU utilization)

# %%
Orchestrator.print_status()
# Out:
# Orchestrator  local_cache=/data-fast/model-cache
#
# GPUs (4):
#   GPU 0: NVIDIA H200  10.9 / 140.4 GiB used  (129.5 GiB free)
#   GPU 1: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 2: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 3: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#
# Models (17):
#   qwen3-0.6b-base              /data-fast/model-cache/Qwen/Qwen3-0.6B-Base
#                                Instance(id=0, gpu=None, pid=85371, state=checkpointed, pinned=1.11 GiB)
#   qwen3-4b-instruct            /data-fast/model-cache/Qwen/Qwen3-4B
#                                Instance(id=3, gpu=None, pid=85458, state=checkpointed, pinned=7.49 GiB)
#   qwen3-4b-thinking-2507       /data-fast/model-cache/Qwen/Qwen3-4B-Thinking-2507
#                                Instance(id=2, gpu=None, pid=85437, state=checkpointed, pinned=7.49 GiB)
#   qwen3-8b-base                /data-fast/model-cache/Qwen/Qwen3-8B-Base
#                                Instance(id=1, gpu=None, pid=85396, state=checkpointed, pinned=15.26 GiB)
#   qwen3-1.7b-instruct          /data-fast/model-cache/Qwen/Qwen3-1.7B
#                                Instance(id=5, gpu=None, pid=87228, state=checkpointed, pinned=3.78 GiB)
#   qwen3-1.7b-base              /data-fast/model-cache/Qwen/Qwen3-1.7B-Base
#                                Instance(id=6, gpu=None, pid=87337, state=checkpointed, pinned=3.20 GiB)
#   qwen3-30b-a3b-thinking-2507  /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Thinking-2507
#                                Instance(id=4, gpu=None, pid=86990, state=checkpointed, pinned=56.87 GiB)
#   qwen3-4b-instruct-2507       /data-fast/model-cache/Qwen/Qwen3-4B-Instruct-2507
#                                Instance(id=9, gpu=None, pid=88605, state=checkpointed, pinned=7.49 GiB)
#   qwen3-30b-a3b-base           /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Base
#                                Instance(id=7, gpu=None, pid=87506, state=checkpointed, pinned=56.87 GiB)
#   qwen3-0.6b-instruct          /data-fast/model-cache/Qwen/Qwen3-0.6B
#                                Instance(id=11, gpu=None, pid=89561, state=checkpointed, pinned=1.40 GiB)
#   qwen3-32b-instruct           /data-fast/model-cache/Qwen/Qwen3-32B
#                                Instance(id=8, gpu=None, pid=88531, state=checkpointed, pinned=61.02 GiB)
#   qwen3-14b-instruct           /data-fast/model-cache/Qwen/Qwen3-14B
#                                Instance(id=10, gpu=None, pid=89335, state=checkpointed, pinned=27.51 GiB)
#   qwen3-30b-a3b-instruct-2507  /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Instruct-2507
#                                Instance(id=12, gpu=None, pid=89640, state=checkpointed, pinned=56.87 GiB)
#   qwen3-4b-base                /data-fast/model-cache/Qwen/Qwen3-4B-Base
#                                Instance(id=14, gpu=None, pid=90874, state=checkpointed, pinned=7.49 GiB)
#   qwen3-14b-base               /data-fast/model-cache/Qwen/Qwen3-14B-Base
#                                Instance(id=13, gpu=None, pid=90495, state=checkpointed, pinned=27.51 GiB)
#   qwen3-8b-instruct            /data-fast/model-cache/Qwen/Qwen3-8B
#                                Instance(id=15, gpu=None, pid=91103, state=checkpointed, pinned=15.26 GiB)
#   qwen3-30b-a3b-instruct       /data-fast/model-cache/Qwen/Qwen3-30B-A3B
#                                Instance(id=16, gpu=None, pid=91688, state=checkpointed, pinned=56.87 GiB)

# %% [markdown]
# Now send all the same example prompt to all models at the same time. First-come, first serve. Later requests will wait until previous requests are done.

# %%
prompt = "Explain the theory of relativity in one sentence."
params = {"max_tokens": 64, "temperature": 0.7}

Orchestrator.generate("qwen3-32b-instruct",             [prompt], params)
Orchestrator.generate("qwen3-14b-instruct",             [prompt], params)
Orchestrator.generate("qwen3-8b-instruct",              [prompt], params)
Orchestrator.generate("qwen3-4b-instruct",              [prompt], params)
Orchestrator.generate("qwen3-1.7b-instruct",            [prompt], params)
Orchestrator.generate("qwen3-0.6b-instruct",            [prompt], params)
Orchestrator.generate("qwen3-30b-a3b-instruct",         [prompt], params)
Orchestrator.generate("qwen3-30b-a3b-base",             [prompt], params)
Orchestrator.generate("qwen3-14b-base",                 [prompt], params)
Orchestrator.generate("qwen3-8b-base",                  [prompt], params)
Orchestrator.generate("qwen3-4b-base",                  [prompt], params)
Orchestrator.generate("qwen3-1.7b-base",                [prompt], params)
Orchestrator.generate("qwen3-0.6b-base",                [prompt], params)
Orchestrator.generate("qwen3-30b-a3b-instruct-2507",    [prompt], params)
Orchestrator.generate("qwen3-4b-instruct-2507",         [prompt], params)
Orchestrator.generate("qwen3-30b-a3b-thinking-2507",    [prompt], params)
Orchestrator.generate("qwen3-4b-thinking-2507",         [prompt], params)

Orchestrator.wait()
# Out:
# qwen3-32b-instruct: generate received
# qwen3-14b-instruct: generate received
# qwen3-32b-instruct: acquired GPU 0
# qwen3-8b-instruct: generate received
# qwen3-4b-instruct: generate received
# qwen3-14b-instruct: acquired GPU 1
# qwen3-1.7b-instruct: generate received
# qwen3-8b-instruct: acquired GPU 2
# qwen3-0.6b-instruct: generate received
# qwen3-4b-instruct: acquired GPU 3
# qwen3-30b-a3b-instruct: generate received
# qwen3-30b-a3b-base: generate received
# qwen3-1.7b-instruct: waiting for GPU...
# qwen3-14b-base: generate received
# qwen3-8b-base: generate received
# qwen3-4b-base: generate received
# qwen3-0.6b-instruct: waiting for GPU...
# qwen3-30b-a3b-instruct: waiting for GPU...
# qwen3-30b-a3b-base: waiting for GPU...
# qwen3-1.7b-base: generate received
# qwen3-14b-base: waiting for GPU...
# qwen3-0.6b-base: generate received
# qwen3-30b-a3b-instruct-2507: generate received
# qwen3-4b-instruct-2507: generate received
# qwen3-30b-a3b-thinking-2507: generate received
# qwen3-8b-base: waiting for GPU...
# qwen3-4b-thinking-2507: generate received
# qwen3-4b-base: waiting for GPU...
# qwen3-1.7b-base: waiting for GPU...
# qwen3-0.6b-base: waiting for GPU...
# qwen3-30b-a3b-instruct-2507: waiting for GPU...
# qwen3-4b-instruct-2507: waiting for GPU...
# qwen3-30b-a3b-thinking-2507: waiting for GPU...
# qwen3-4b-thinking-2507: waiting for GPU...
# qwen3-4b-instruct: generated (wait=0.0s, restore=2.5s, generate=0.3s, checkpoint=1.6s, total=4.3s) -> " The theory of relativity, formulated by Albert Einstein, describes how gravity is a curvature of sp"
# qwen3-30b-a3b-instruct: acquired GPU 3
# qwen3-8b-instruct: generated (wait=0.0s, restore=2.8s, generate=0.4s, checkpoint=1.7s, total=4.9s) -> " The theory of relativity, developed by Albert Einstein, posits that the laws of physics are the sam"
# qwen3-30b-a3b-thinking-2507: acquired GPU 2
# qwen3-14b-instruct: generated (wait=0.0s, restore=3.8s, generate=0.6s, checkpoint=2.9s, total=7.4s) -> " The theory of relativity, developed by Albert Einstein, posits that the laws of physics are the sam"
# qwen3-8b-base: acquired GPU 1
# qwen3-32b-instruct: generated (wait=0.0s, restore=5.5s, generate=1.2s, checkpoint=3.4s, total=10.1s) -> " The theory of relativity, formulated by Albert Einstein, explains how the laws of physics are the s"
# qwen3-4b-base: acquired GPU 0
# qwen3-8b-base: generated (wait=7.3s, restore=1.9s, generate=0.2s, checkpoint=2.4s, total=11.8s) -> " The theory of relativity, developed by Albert Einstein, explains how space and time are interconnec"
# qwen3-4b-thinking-2507: acquired GPU 1
# qwen3-30b-a3b-instruct: generated (wait=4.3s, restore=6.4s, generate=0.3s, checkpoint=2.9s, total=13.8s) -> " The theory of relativity is a fundamental physical theory that describes the relationship between s"
# qwen3-0.6b-instruct: acquired GPU 3
# qwen3-4b-base: generated (wait=10.1s, restore=2.3s, generate=0.1s, checkpoint=3.0s, total=15.5s) -> " The theory of relativity suggests that space and time are relative, and that they are interconnecte"
# qwen3-1.7b-instruct: acquired GPU 0
# qwen3-30b-a3b-thinking-2507: generated (wait=4.9s, restore=6.3s, generate=0.3s, checkpoint=4.0s, total=15.5s) -> " The theory of relativity, developed by Albert Einstein, fundamentally changed our understanding of "
# qwen3-14b-base: acquired GPU 2
# qwen3-0.6b-instruct: generated (wait=13.9s, restore=2.8s, generate=0.1s, checkpoint=1.3s, total=18.2s) -> " Also, explain the theory of quantum mechanics in one sentence. Answer: The theory of **relativity**"
# qwen3-4b-instruct-2507: acquired GPU 3
# qwen3-1.7b-instruct: generated (wait=15.5s, restore=1.5s, generate=0.2s, checkpoint=1.6s, total=18.7s) -> " The theory of relativity, formulated by Albert Einstein, consists of two parts: special relativity "
# qwen3-0.6b-base: acquired GPU 0
# qwen3-4b-thinking-2507: generated (wait=11.8s, restore=4.4s, generate=0.3s, checkpoint=2.6s, total=19.2s) -> " Explain the theory of relativity in one sentence.  Okay, the user asked me to explain the theory of"
# qwen3-30b-a3b-base: acquired GPU 1
# qwen3-0.6b-base: generated (wait=18.7s, restore=1.8s, generate=0.1s, checkpoint=1.4s, total=22.0s) -> " The theory of relativity, proposed by Albert Einstein, explains how the laws of physics are the sam"
# qwen3-30b-a3b-instruct-2507: acquired GPU 0
# qwen3-4b-instruct-2507: generated (wait=18.1s, restore=2.6s, generate=0.3s, checkpoint=2.3s, total=23.4s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"
# qwen3-1.7b-base: acquired GPU 3
# qwen3-14b-base: generated (wait=15.5s, restore=5.2s, generate=0.6s, checkpoint=3.2s, total=24.5s) -> " The theory of relativity, formulated by Albert Einstein, consists of two parts: special relativity "
# qwen3-1.7b-base: generated (wait=23.4s, restore=2.9s, generate=0.1s, checkpoint=1.4s, total=27.8s) -> " The theory of relativity suggests that the laws of physics are the same for all observers, regardle"
# qwen3-30b-a3b-base: generated (wait=19.2s, restore=7.6s, generate=0.1s, checkpoint=2.6s, total=29.5s) -> " The theory of relativity is a set of physical principles that describe the relationship between spa"
# qwen3-30b-a3b-instruct-2507: generated (wait=22.0s, restore=7.6s, generate=0.3s, checkpoint=2.5s, total=32.4s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"

# %% [markdown]
# Now lets add 2 seconds intervals between each request. We will see less wait times.

# %%
from time import sleep

Orchestrator.generate("qwen3-32b-instruct",             [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-14b-instruct",             [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-8b-instruct",              [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-4b-instruct",              [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-1.7b-instruct",            [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-0.6b-instruct",            [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-30b-a3b-instruct",         [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-30b-a3b-base",             [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-14b-base",                 [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-8b-base",                  [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-4b-base",                  [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-1.7b-base",                [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-0.6b-base",                [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-30b-a3b-instruct-2507",    [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-4b-instruct-2507",         [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-30b-a3b-thinking-2507",    [prompt], params)
sleep(2)
Orchestrator.generate("qwen3-4b-thinking-2507",         [prompt], params)

Orchestrator.wait()
# Out:
# qwen3-32b-instruct: generate received
# qwen3-32b-instruct: acquired GPU 0
# qwen3-14b-instruct: generate received
# qwen3-14b-instruct: acquired GPU 1
# qwen3-8b-instruct: generate received
# qwen3-8b-instruct: acquired GPU 2
# qwen3-4b-instruct: generate received
# qwen3-4b-instruct: acquired GPU 3
# qwen3-14b-instruct: generated (wait=0.0s, restore=2.7s, generate=0.5s, checkpoint=1.9s, total=5.1s) -> " The theory of relativity, developed by Albert Einstein, posits that the laws of physics are the sam"
# qwen3-1.7b-instruct: generate received
# qwen3-1.7b-instruct: acquired GPU 1
# qwen3-32b-instruct: generated (wait=0.0s, restore=4.7s, generate=1.2s, checkpoint=2.4s, total=8.3s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"
# qwen3-8b-instruct: generated (wait=0.0s, restore=2.0s, generate=0.3s, checkpoint=2.6s, total=4.9s) -> " The theory of relativity, developed by Albert Einstein, posits that the laws of physics are the sam"
# qwen3-0.6b-instruct: generate received
# qwen3-0.6b-instruct: acquired GPU 0
# qwen3-4b-instruct: generated (wait=0.0s, restore=3.2s, generate=0.2s, checkpoint=1.5s, total=4.9s) -> " The theory of relativity, formulated by Albert Einstein, describes how gravity arises from the curv"
# qwen3-1.7b-instruct: generated (wait=0.0s, restore=2.0s, generate=0.1s, checkpoint=1.6s, total=3.8s) -> " The theory of relativity, developed by Albert Einstein, consists of two parts: special relativity a"
# qwen3-30b-a3b-instruct: generate received
# qwen3-30b-a3b-instruct: acquired GPU 1
# qwen3-0.6b-instruct: generated (wait=0.0s, restore=1.3s, generate=0.1s, checkpoint=1.7s, total=3.1s) -> " Let me know if you need a summary of the theory of relativity or a general explanation of the conce"
# qwen3-30b-a3b-base: generate received
# qwen3-30b-a3b-base: acquired GPU 0
# qwen3-14b-base: generate received
# qwen3-14b-base: acquired GPU 2
# qwen3-8b-base: generate received
# qwen3-8b-base: acquired GPU 3
# qwen3-30b-a3b-instruct: generated (wait=0.0s, restore=4.4s, generate=0.3s, checkpoint=2.8s, total=7.4s) -> " The theory of relativity, developed by Albert Einstein, describes how the laws of physics are the s"
# qwen3-4b-base: generate received
# qwen3-4b-base: acquired GPU 1
# qwen3-1.7b-base: generate received
# qwen3-1.7b-base: waiting for GPU...
# qwen3-14b-base: generated (wait=0.0s, restore=3.4s, generate=0.3s, checkpoint=2.5s, total=6.2s) -> " The theory of relativity states that the laws of physics are the same for all observers in uniform "
# qwen3-1.7b-base: acquired GPU 2
# qwen3-30b-a3b-base: generated (wait=0.0s, restore=5.5s, generate=0.2s, checkpoint=4.2s, total=10.0s) -> " The theory of relativity is a theory in physics which states that the laws of physics are the same "
# qwen3-0.6b-base: generate received
# qwen3-0.6b-base: acquired GPU 0
# qwen3-8b-base: generated (wait=0.0s, restore=2.9s, generate=0.3s, checkpoint=3.5s, total=6.6s) -> " The theory of relativity, developed by Albert Einstein, posits that the laws of physics are the sam"
# qwen3-30b-a3b-instruct-2507: generate received
# qwen3-30b-a3b-instruct-2507: acquired GPU 3
# qwen3-4b-base: generated (wait=0.0s, restore=2.2s, generate=0.1s, checkpoint=3.8s, total=6.1s) -> " The theory of relativity is a physics framework that describes the relationship between space and t"
# qwen3-1.7b-base: generated (wait=0.2s, restore=2.9s, generate=0.1s, checkpoint=1.4s, total=4.6s) -> " The theory of relativity, formulated by Albert Einstein, is a revolutionary framework that integrat"
# qwen3-0.6b-base: generated (wait=0.0s, restore=1.9s, generate=0.1s, checkpoint=1.6s, total=3.5s) -> " The theory of relativity, developed by Albert Einstein, is a comprehensive framework for understand"
# qwen3-4b-instruct-2507: generate received
# qwen3-4b-instruct-2507: acquired GPU 0
# qwen3-30b-a3b-thinking-2507: generate received
# qwen3-30b-a3b-thinking-2507: acquired GPU 1
# qwen3-4b-instruct-2507: generated (wait=0.0s, restore=1.4s, generate=0.2s, checkpoint=1.7s, total=3.4s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"
# qwen3-4b-thinking-2507: generate received
# qwen3-4b-thinking-2507: acquired GPU 0
# qwen3-30b-a3b-instruct-2507: generated (wait=0.0s, restore=5.5s, generate=0.3s, checkpoint=2.7s, total=8.6s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"
# qwen3-4b-thinking-2507: generated (wait=0.0s, restore=1.4s, generate=0.2s, checkpoint=2.4s, total=4.1s) -> " The theory of relativity, developed by Albert Einstein, states that the laws of physics are the sam"
# qwen3-30b-a3b-thinking-2507: generated (wait=0.0s, restore=4.8s, generate=0.3s, checkpoint=2.6s, total=7.7s) -> " The theory of relativity, developed by Albert Einstein, revolutionizes our understanding of space, "

# %%
Orchestrator.print_status()
# Out:
# Orchestrator  local_cache=/data-fast/model-cache
#
# GPUs (4):
#   GPU 0: NVIDIA H200  10.9 / 140.4 GiB used  (129.5 GiB free)
#   GPU 1: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 2: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 3: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#
# Models (17):
#   qwen3-0.6b-base              /data-fast/model-cache/Qwen/Qwen3-0.6B-Base
#                                Instance(id=0, gpu=None, pid=85371, state=checkpointed, pinned=1.11 GiB)
#   qwen3-4b-instruct            /data-fast/model-cache/Qwen/Qwen3-4B
#                                Instance(id=3, gpu=None, pid=85458, state=checkpointed, pinned=7.49 GiB)
#   qwen3-4b-thinking-2507       /data-fast/model-cache/Qwen/Qwen3-4B-Thinking-2507
#                                Instance(id=2, gpu=None, pid=85437, state=checkpointed, pinned=7.49 GiB)
#   qwen3-8b-base                /data-fast/model-cache/Qwen/Qwen3-8B-Base
#                                Instance(id=1, gpu=None, pid=85396, state=checkpointed, pinned=15.26 GiB)
#   qwen3-1.7b-instruct          /data-fast/model-cache/Qwen/Qwen3-1.7B
#                                Instance(id=5, gpu=None, pid=87228, state=checkpointed, pinned=3.78 GiB)
#   qwen3-1.7b-base              /data-fast/model-cache/Qwen/Qwen3-1.7B-Base
#                                Instance(id=6, gpu=None, pid=87337, state=checkpointed, pinned=3.20 GiB)
#   qwen3-30b-a3b-thinking-2507  /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Thinking-2507
#                                Instance(id=4, gpu=None, pid=86990, state=checkpointed, pinned=56.87 GiB)
#   qwen3-4b-instruct-2507       /data-fast/model-cache/Qwen/Qwen3-4B-Instruct-2507
#                                Instance(id=9, gpu=None, pid=88605, state=checkpointed, pinned=7.49 GiB)
#   qwen3-30b-a3b-base           /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Base
#                                Instance(id=7, gpu=None, pid=87506, state=checkpointed, pinned=56.87 GiB)
#   qwen3-0.6b-instruct          /data-fast/model-cache/Qwen/Qwen3-0.6B
#                                Instance(id=11, gpu=None, pid=89561, state=checkpointed, pinned=1.40 GiB)
#   qwen3-32b-instruct           /data-fast/model-cache/Qwen/Qwen3-32B
#                                Instance(id=8, gpu=None, pid=88531, state=checkpointed, pinned=61.02 GiB)
#   qwen3-14b-instruct           /data-fast/model-cache/Qwen/Qwen3-14B
#                                Instance(id=10, gpu=None, pid=89335, state=checkpointed, pinned=27.51 GiB)
#   qwen3-30b-a3b-instruct-2507  /data-fast/model-cache/Qwen/Qwen3-30B-A3B-Instruct-2507
#                                Instance(id=12, gpu=None, pid=89640, state=checkpointed, pinned=56.87 GiB)
#   qwen3-4b-base                /data-fast/model-cache/Qwen/Qwen3-4B-Base
#                                Instance(id=14, gpu=None, pid=90874, state=checkpointed, pinned=7.49 GiB)
#   qwen3-14b-base               /data-fast/model-cache/Qwen/Qwen3-14B-Base
#                                Instance(id=13, gpu=None, pid=90495, state=checkpointed, pinned=27.51 GiB)
#   qwen3-8b-instruct            /data-fast/model-cache/Qwen/Qwen3-8B
#                                Instance(id=15, gpu=None, pid=91103, state=checkpointed, pinned=15.26 GiB)
#   qwen3-30b-a3b-instruct       /data-fast/model-cache/Qwen/Qwen3-30B-A3B
#                                Instance(id=16, gpu=None, pid=91688, state=checkpointed, pinned=56.87 GiB)

# %% [markdown]
# The model registration takes disk and CPU resources until it is removed from the registry.

# %%
Orchestrator.remove()

Orchestrator.wait()
Orchestrator.print_status()
# Out:
# qwen3-0.6b-base: remove received
# qwen3-4b-instruct: remove received
# qwen3-4b-thinking-2507: remove received
# qwen3-8b-base: remove received
# qwen3-1.7b-instruct: remove received
# qwen3-1.7b-base: remove received
# qwen3-30b-a3b-thinking-2507: remove received
# qwen3-4b-instruct-2507: remove received
# qwen3-30b-a3b-base: remove received
# qwen3-0.6b-instruct: remove received
# qwen3-32b-instruct: remove received
# qwen3-14b-instruct: remove received
# qwen3-30b-a3b-instruct-2507: remove received
# qwen3-4b-base: remove received
# qwen3-14b-base: remove received
# qwen3-8b-instruct: remove received
# qwen3-30b-a3b-instruct: remove received
# qwen3-0.6b-instruct: removed
# qwen3-0.6b-base: removed
# qwen3-1.7b-instruct: removed
# qwen3-1.7b-base: removed
# qwen3-4b-base: removed
# qwen3-4b-instruct: removed
# qwen3-4b-instruct-2507: removed
# qwen3-8b-instruct: removed
# qwen3-4b-thinking-2507: removed
# qwen3-8b-base: removed
# qwen3-14b-base: removed
# qwen3-14b-instruct: removed
# qwen3-30b-a3b-base: removed
# qwen3-30b-a3b-instruct: removed
# qwen3-30b-a3b-instruct-2507: removed
# qwen3-32b-instruct: removed
# qwen3-30b-a3b-thinking-2507: removed
#
# Orchestrator  local_cache=/data-fast/model-cache
#
# GPUs (4):
#   GPU 0: NVIDIA H200  10.9 / 140.4 GiB used  (129.5 GiB free)
#   GPU 1: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 2: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#   GPU 3: NVIDIA H200  0.6 / 140.4 GiB used  (139.8 GiB free)
#
# No models registered.
